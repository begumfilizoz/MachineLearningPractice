# %%
#This model uses the breast cancer Wisconsin data set to predict the existence breast cancer within these samples

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data.csv')

# %%
#Showing the first few items in the dataset

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
#Removing unnecessary columns

# %%
df = df.drop(columns='id', axis = 1)

# %%
df = df.drop(columns='Unnamed: 32', axis = 1)

# %%
df.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
#Labeling malignant cells as 1, benign ones as 0

# %%
df['diagnosis'] = df['diagnosis'].map({'M' : 1, 'B' : 0})

# %%
df.head()
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          1        17.99         10.38          122.80     1001.0
# 1          1        20.57         17.77          132.90     1326.0
# 2          1        19.69         21.25          130.00     1203.0
# 3          1        11.42         20.38           77.58      386.1
# 4          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
df.columns
# Out:
# Index(['diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
mean_features = list(df.columns[1:11])
se_features = list(df.columns[11:21])
worst_features = list(df.columns[21:31])

# %%
print(se_features)
# Out:
# ['radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se', 'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se', 'fractal_dimension_se']

# %%
mean_features.append('diagnosis')
se_features.append('diagnosis')
worst_features.append('diagnosis')

# %%
corr = df[worst_features].corr()

# %%
corr
# Out:
#                          radius_worst  texture_worst  perimeter_worst  \
# radius_worst                 1.000000       0.359921         0.993708
# texture_worst                0.359921       1.000000         0.365098
# perimeter_worst              0.993708       0.365098         1.000000
# area_worst                   0.984015       0.345842         0.977578
# smoothness_worst             0.216574       0.225429         0.236775
# compactness_worst            0.475820       0.360832         0.529408
# concavity_worst              0.573975       0.368366         0.618344
# concave points_worst         0.787424       0.359755         0.816322
# symmetry_worst               0.243529       0.233027         0.269493
# fractal_dimension_worst      0.093492       0.219122         0.138957
# diagnosis                    0.776454       0.456903         0.782914
#
#                          area_worst  smoothness_worst  compactness_worst  \
# ...

# %%
#Training the model

# %%
prediction_vars = ['radius_mean', 'perimeter_mean', 'area_mean', 'compactness_mean', 'concavity_mean', 'concave points_mean', 'radius_se', 'area_se', 'radius_worst', 'perimeter_worst', 'compactness_worst']

# %%
df
# Out:
#      diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0            1        17.99         10.38          122.80     1001.0
# 1            1        20.57         17.77          132.90     1326.0
# 2            1        19.69         21.25          130.00     1203.0
# 3            1        11.42         20.38           77.58      386.1
# 4            1        20.29         14.34          135.10     1297.0
# ..         ...          ...           ...             ...        ...
# 564          1        21.56         22.39          142.00     1479.0
# 565          1        20.13         28.25          131.20     1261.0
# 566          1        16.60         28.08          108.30      858.1
# 567          1        20.60         29.33          140.10     1265.0
# 568          0         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
from sklearn.model_selection import train_test_split
train, test = train_test_split(df, test_size = 0.15, random_state = 1)

# %%
train_x = train[prediction_vars]
train_y = train['diagnosis']
test_x = test[prediction_vars]
test_y = test['diagnosis']

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC

# %%
model = RandomForestClassifier()

# %%
model.fit(train_x, train_y)
# Out:
# RandomForestClassifier()

# %%
predictions = model.predict(test_x)

# %%
test_y
# Out:
# 421    0
# 47     1
# 292    0
# 186    1
# 414    1
#       ..
# 335    1
# 308    0
# 370    1
# 403    0
# 120    0
# Name: diagnosis, Length: 86, dtype: int64

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(test_y, predictions)
# Out:
# array([[51,  1],
#        [ 6, 28]])

# %%
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score

# %%
#Evaluating our results

# %%
precision = precision_score(test_y, predictions)

# %%
print("This is the precision of the predictions: %.3f" % precision)
# Out:
# This is the precision of the predictions: 0.966

# %%
recall = recall_score(test_y, predictions)

# %%
print("This is the recall of the predictions: %.3f" % recall)
# Out:
# This is the recall of the predictions: 0.824

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy = accuracy_score(test_y, predictions)

# %%
print("This is the accuracy of the predictions: %.3f" % accuracy)
# Out:
# This is the accuracy of the predictions: 0.919
